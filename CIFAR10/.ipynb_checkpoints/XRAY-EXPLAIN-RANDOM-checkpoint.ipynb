# %%
#Importing Necessary Libraries.

from PIL import Image
import numpy as np
import pandas as pd 
import os
import re
import cv2
from pathlib import Path

import matplotlib.pyplot as P
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4024)])
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

import lime
from lime import lime_image

import saliency.core as saliency
import glob2

tf.__version__
# Out:
# '2.2.0'

# %%
INPUT_DIR = "/home/maia/Documents/Universidade/Universidade/UNIVERSIDADE/MESTRADO/CADEIRAS/FPCC2/CIFAR10/cifar10/test_eval"
OUTPUT_DIR = "./OUT/EVAL_EXPLAIN/"
INPUT_FILES = glob2.glob(os.path.join(INPUT_DIR, "*.png"))
MODELS_FILES = ['/home/maia/Documents/Universidade/Universidade/UNIVERSIDADE/MESTRADO/CADEIRAS/FPCC2/CIFAR10/OUT/TRUE_MODEL_1500_DROP/TRUE_MODEL_1500_DROP_w00300.h5']
#, "/home/maia/Documents/Universidade/Universidade/UNIVERSIDADE/MESTRADO/CADEIRAS/FPCC2/CIFAR10/OUT_RANDOM/RANDOM_MODEL_1024/RANDOM_MODEL_1024_w01150.h5"

# %%
def image_generator(directory, res):
    test_datagen = ImageDataGenerator(rescale=1/255)
    image_generator = test_datagen.flow_from_directory(
            directory,
            target_size=(res, res),
            batch_size=1,
            shuffle=False,
            class_mode='categorical')
    return image_generator

# %%
class_idx_str = 'class_idx_str'
def call_model_function(images, call_model_args=None, expected_keys=None):
    target_class_idx =  call_model_args[class_idx_str]
    images = tf.convert_to_tensor(images)
    with tf.GradientTape() as tape:
        if expected_keys==[saliency.base.INPUT_OUTPUT_GRADIENTS]:
            tape.watch(images)
            _, output_layer = model(images)
            output_layer = output_layer[:,target_class_idx]
            gradients = np.array(tape.gradient(output_layer, images))
            return {saliency.base.INPUT_OUTPUT_GRADIENTS: gradients}
        else:
            conv_layer, output_layer = model(images)
            gradients = np.array(tape.gradient(output_layer, conv_layer))
            return {saliency.base.CONVOLUTION_LAYER_VALUES: conv_layer,
                    saliency.base.CONVOLUTION_OUTPUT_GRADIENTS: gradients}

# %%
def save_greyscale(out_dir, out_file, mask):
    Path.mkdir(Path(out_dir), parents=True, exist_ok=True)
    cv2.imwrite(str(Path(out_dir) / out_file),  cv2.cvtColor(mask*255,cv2.COLOR_GRAY2RGB))

def save_rgb(out_dir, out_file, mask):
    Path.mkdir(Path(out_dir), parents=True, exist_ok=True)
    cv2.imwrite(str(Path(out_dir) / out_file), cv2.cvtColor(image, cv2.COLOR_RGB2BGR))
    
def save_heat(out_dir, out_file, mask):
    Path.mkdir(Path(out_dir), parents=True, exist_ok=True)
    plt.imsave(str(Path(out_dir) / out_file), arr = mask, cmap='gray', vmin = 0, vmax = 255)
    
def save_heat_image(out_dir, out_file, mask):
    Path.mkdir(Path(out_dir), parents=True, exist_ok=True)
    P.imsave(str(Path(out_dir) / out_file), arr = mask, cmap='gray')
    
def save_lime(out_dir, out_file, mask):
    Path.mkdir(Path(out_dir), parents=True, exist_ok=True)
    P.imsave(str(Path(out_dir) / out_file), arr = mask, cmap='gray', vmin= -mask.max(), vmax=mask.max())
    
def save_blur(out_dir, out_file, mask):
    Path.mkdir(Path(out_dir), parents=True, exist_ok=True)
    P.imsave(str(Path(out_dir) / out_file), arr = mask, cmap=P.cm.gray, vmin=0, vmax=1)
    
from matplotlib import pylab as P
def ShowImage(im, title='', ax=None):
    if ax is None:
        P.figure()
    P.axis('off')
    P.imshow(im)
    P.title(title)

def ShowGrayscaleImage(im, file,  title='', ax=None):
    if ax is None:
        P.figure()
    P.axis('off')
    P.imsave(file, im, cmap=P.cm.gray, vmin=0, vmax=1)

def ShowHeatMap(im, file, ax=None):
    if ax is None:
        P.figure()
    P.axis('off')
    P.imsave(file, im, cmap='grey')

# %%
def explain_and_saveCAM(model, image, image_label_target, out_dir, out_file):
    call_model_args = {class_idx_str: image_label_target}
    
    im=image[0]
    
    gradient_saliency = saliency.GradientSaliency()
    vanilla_mask_3d = gradient_saliency.GetMask(im, call_model_function, call_model_args)
    GradientSaliency = saliency.VisualizeImageGrayscale(vanilla_mask_3d)
    save_greyscale(out_dir+"/GradientSaliency/", out_file, GradientSaliency)
    
    '''smoothgrad_mask_3d = gradient_saliency.GetSmoothedMask(im, call_model_function, call_model_args)
    SmoothGradientSaliency = saliency.VisualizeImageGrayscale(smoothgrad_mask_3d)
    save_greyscale(out_dir+"/SmoothGradientSaliency/", out_file, SmoothGradientSaliency)
    
    
    integrated_gradients = saliency.IntegratedGradients()
    baseline = np.zeros(im.shape)
    vanilla_integrated_gradients_mask_3d = integrated_gradients.GetMask(
      im, call_model_function, call_model_args, x_steps=25, x_baseline=baseline, batch_size=20)
    vanilla_mask_grayscale = saliency.VisualizeImageGrayscale(vanilla_integrated_gradients_mask_3d)
    save_greyscale(out_dir+"/IntegratedGradientSaliency/", out_file, vanilla_mask_grayscale.astype('float32'))

    smoothgrad_integrated_gradients_mask_3d = integrated_gradients.GetSmoothedMask(
      im, call_model_function, call_model_args, x_steps=25, x_baseline=baseline, batch_size=20)
    smoothgrad_mask_grayscale = saliency.VisualizeImageGrayscale(smoothgrad_integrated_gradients_mask_3d)
    save_greyscale(out_dir+"/SmoothIntegratedGradientSaliency/", out_file, smoothgrad_mask_grayscale.astype('float32'))
    
    
    blur_ig = saliency.BlurIG()
    blur_ig_mask_3d = blur_ig.GetMask(im, call_model_function, call_model_args, batch_size=20)
    blur_ig_mask_grayscale = saliency.VisualizeImageGrayscale(blur_ig_mask_3d)
    save_blur(out_dir+"/Blur/", out_file, blur_ig_mask_grayscale)

    xrai_object = saliency.XRAI()
    xrai_attributions = xrai_object.GetMask(im, call_model_function, call_model_args, batch_size=20)
    save_heat_image(out_dir+"/XRAI/", out_file, xrai_attributions)'''
    
    grad_cam = saliency.GradCam()
    smooth_grad_cam_mask_3d = grad_cam.GetSmoothedMask(im, call_model_function, call_model_args)
    smooth_grad_cam_mask_grayscale = saliency.VisualizeImageGrayscale(smooth_grad_cam_mask_3d)
    save_heat_image(out_dir+"/SmoothGradCAM/", out_file, smooth_grad_cam_mask_grayscale)

# %%
for model_path in MODELS_FILES:
    res = 32
    m = tf.keras.models.load_model(model_path)
    conv_layer = m.get_layer('conv2d_1')
    model = tf.keras.models.Model([m.inputs], [conv_layer.output, m.output])
    model_name = os.path.splitext(model_path.split("/")[-1])[0]
    generator = image_generator(INPUT_DIR, res)
    generator.reset()
    batch_index = 0
    while batch_index <= generator.batch_index:
        image, _ = generator.next()
        batch_index = batch_index + 1
        idx = generator.batch_index - 1
        image_path = generator.filenames[idx]
        image_file = image_path.split("/")[-1]
        folder = image_path.split("/")[-2]
        filename, fileext = os.path.splitext(image_file)
        categorical_label = generator.classes[idx]
        categorical_label_oh = to_categorical(categorical_label, num_classes=len(np.unique(generator.classes)))
        explain_and_saveCAM(model, image, categorical_label, OUTPUT_DIR, folder+filename+model_name+".png")
# Out:
# Found 500 images belonging to 10 classes.

# %%
for model_path in  MODELS_FILES:
    res = 224
    model = tf.keras.models.load_model(model_path)
    model_name = os.path.splitext(model_path.split("/")[-1])[0]
    generator = image_generator(INPUT_DIR, res)
    generator.reset()
    batch_index = 0
    while batch_index <= generator.batch_index:
        image, _ = generator.next()
        batch_index = batch_index + 1
        idx = generator.batch_index - 1
        image_path = generator.filenames[idx]
        image_file = image_path.split("/")[-1]
        filename, fileext = os.path.splitext(image_file)
        categorical_label = generator.classes[idx]
        categorical_label_oh = to_categorical(categorical_label, num_classes=len(np.unique(generator.classes)))
        explainer = lime_image.LimeImageExplainer(verbose=True)
        print(image.shape)
        explanation = explainer.explain_instance(image[0].astype('double'), model.predict, top_labels=2, hide_color=0, num_samples=100)
        
        ind =  explanation.top_labels[categorical_label]
        #Map each explanation weight to the corresponding superpixel
        dict_heatmap = dict(explanation.local_exp[ind])
        heatmap = np.vectorize(dict_heatmap.get)(explanation.segments) 

        #Plot. The visualization makes more sense if a symmetrical colorbar is used.
        
        save_lime(OUTPUT_DIR+"/LIME/", filename+model_name+".png", heatmap)

# %%
for model_path in  MODELS_FILES:
    res = 224
    model = tf.keras.models.load_model(model_path)
    model_name = os.path.splitext(model_path.split("/")[-1])[0]
    generator = image_generator(INPUT_DIR, res)
    generator.reset()
    batch_index = 0
    while batch_index <= generator.batch_index:
        image, _ = generator.next()
        batch_index = batch_index + 1
        idx = generator.batch_index - 1
        image_path = generator.filenames[idx]
        image_file = image_path.split("/")[-1]
        filename, fileext = os.path.splitext(image_file)
        categorical_label = generator.classes[idx]
        categorical_label_oh = to_categorical(categorical_label, num_classes=len(np.unique(generator.classes)))
        explainer = RISE()
        heatmaps, masks = explainer.explain(image[0],model)
        save_lime(OUTPUT_DIR+"/RISE/", filename+model_name+".png", heatmaps[idx])
# Out:
# 224
# Found 50 images belonging to 2 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4b7ae25b8588> in <module>
#      12         categorical_label_oh = to_categorical(categorical_label, num_classes=len(np.unique(generator.classes)))
#      13         explainer = RISE()
# ---> 14         heatmaps, masks = explainer.explain(image[0],model)
#      15         save_lime(OUTPUT_DIR+"/RISE/", filename+model_name+".png", heatmaps[idx])
#      16
#
# ~/Documents/Universidade/Universidade/UNIVERSIDADE/EXPERIMENTO/2EXPLAIN/XRAY/explain_image.py in explain(self, inp, model, preprocessing_fn, masks_user, N, s, p1, verbose, batch_size, mode)
#     135             masked = image*masks_batch + fudged_image*(1-masks_batch)
#     136
# --> 137             to_append = model.predict(masked)
#     138
#     139             preds.append(to_append)
#
# ...

# %%
generator = image_generator(INPUT_DIR, 224)
generator.reset()
batch_index = 0
while batch_index <= generator.batch_index:
    image, _ = generator.next()
    batch_index = batch_index + 1
    idx = generator.batch_index -1
    image_path = generator.filenames[idx]
    image_file = image_path.split("/")[-1]
    filename, fileext = os.path.splitext(image_file)
    print(filename)
    P.imshow(image[0]/255)
    P.show()
# Out:
# Found 50 images belonging to 2 classes.
# NORMAL-1049278-0001
# NORMAL-1110860-0001
# NORMAL-1160949-0001
# NORMAL-1212407-0001
# NORMAL-1228182-0001
# NORMAL-186900-0001
# NORMAL-217318-0001
# NORMAL-283245-0001
# NORMAL-284601-0001
# NORMAL-472699-0001
# NORMAL-520267-0001
# NORMAL-522391-0001
# NORMAL-528189-0001
# NORMAL-541071-0001
# NORMAL-561684-0001
# NORMAL-630880-0001
# NORMAL-667173-0001
# NORMAL-706052-0001
# NORMAL-724740-0001
# NORMAL-745902-0001
# NORMAL-754920-0001
# NORMAL-786023-0001
# NORMAL-857568-0001
# NORMAL-870639-0001
# NORMAL-976006-0001
# BACTERIA-9364007-0003
# BACTERIA-9503383-0001
# BACTERIA-9673743-0001
# BACTERIA-9673743-0002
# BACTERIA-9673743-0003
# BACTERIA-9764136-0001
# BACTERIA-9857270-0001
# BACTERIA-9857270-0002
# BACTERIA-9857270-0003
# BACTERIA-9857270-0004
# BACTERIA-9913238-0001
# BACTERIA-9913238-0002
# BACTERIA-9913238-0003
# VIRUS-131422-0001
# VIRUS-258000-0001
# VIRUS-262135-0001
# VIRUS-280992-0001
# VIRUS-30184-0001
# ...

# %%
call_model_args = {class_idx_str: image_label_target}
im=image[0]
grad_cam = saliency.GradCam()

# Compute the Grad-CAM mask and Smoothgrad+Grad-CAM mask.
grad_cam_mask_3d = grad_cam.GetMask(im, call_model_function, call_model_args)
smooth_grad_cam_mask_3d = grad_cam.GetSmoothedMask(im, call_model_function, call_model_args)
print(grad_cam_mask_3d)

# Call the visualization methods to convert the 3D tensors to 2D grayscale.
grad_cam_mask_grayscale = saliency.VisualizeImageGrayscale(grad_cam_mask_3d)
smooth_grad_cam_mask_grayscale = saliency.VisualizeImageGrayscale(smooth_grad_cam_mask_3d)

# Set up matplot lib figures.
ROWS = 1
COLS = 2
UPSCALE_FACTOR = 10
P.figure(figsize=(ROWS * UPSCALE_FACTOR, COLS * UPSCALE_FACTOR))

# Render the saliency masks.
ShowGrayscaleImage(grad_cam_mask_grayscale, title='Grad-CAM', ax=P.subplot(ROWS, COLS, 1))
ShowGrayscaleImage(smooth_grad_cam_mask_grayscale, title='Smoothgrad Grad-CAM', ax=P.subplot(ROWS, COLS, 2))
